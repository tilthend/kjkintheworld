# %% [markdown]
# #### 인구 데이터 활용한 데이터 분석

# %%
import csv

# %%
data = csv.reader(f)
f = open('age_gender.csv')

next(data)

home = []

name = input('인구 구조가 알고 싶은 지역의 이름(동 단위)을 입력해 주세요 : ')

for row in data :
    if name in row[0] : 
        for i in row[3:] :
            home.append(int(i))

print(home)
# Out:
# 인구 구조가 알고 싶은 지역의 이름(동 단위)을 입력해 주세요 : 방이2동
# [136, 137, 129, 134, 130, 143, 105, 96, 102, 106, 97, 100, 95, 118, 122, 118, 130, 131, 138, 217, 263, 284, 308, 361, 422, 541, 647, 720, 783, 771, 714, 730, 657, 607, 571, 563, 543, 532, 516, 514, 463, 412, 343, 356, 338, 315, 339, 366, 335, 404, 372, 376, 381, 387, 330, 340, 346, 326, 365, 444, 411, 387, 351, 353, 299, 339, 313, 245, 256, 206, 176, 202, 180, 179, 150, 137, 137, 111, 126, 106, 74, 69, 59, 56, 44, 45, 43, 31, 33, 21, 14, 9, 16, 8, 4, 4, 4, 4, 6, 1, 3]

# %%
import numpy as np
import csv

f = open('age11.csv')
data = csv.reader(f)

next(data)

name = input('인구 구조가 알고 싶은 지역의 이름(동 단위)을 입력해 주세요 : ')

for row in data :
    if name in row[0] : 
            home = np.array(row[3:], dtype=int)

import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')
plt.title(name+'지역의 인구 구조')
plt.plot(home)

plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(동 단위)을 입력해 주세요 : 방이2동

# %%
import numpy as np
import csv

f = open('age11.csv')
data = csv.reader(f)

next(data)
home = []
name = input('인구 구조가 알고 싶은 지역의 이름(동 단위)을 입력해 주세요 : ')

for row in data :
    if name in row[0] : 
        for i in row[3:] :
            home.append(int(i))

import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')
plt.title(name+'지역의 인구 구조')
plt.plot(home)

plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(동 단위)을 입력해 주세요 : 방이2동

# %%
import numpy as np
import csv

f = open('age11.csv')
data = csv.reader(f)
next(data)
data = list(data)

name = input('인구 구조가 알고 싶은 지역의 이름(동 단위)을 입력해 주세요 : ')
mn = 1
result_name=''
result = 0

for row in data :
    if name in row[0] : 
            home = np.array(row[3:], dtype=int)/int(row[2])

for row in data :
    away = np.array(row[3:], dtype=int)/int(row[2])
    s = np.sum((homw-away)**2)
    if s < mn and name not in row[0] :
        mn = s
        result_name = row[0]
        result = away
            
            
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(10, 5), dpi=300)
plt.rc('font', family='Malgun Gothic')
plt.title(name+'지역의 인구 구조')
plt.plot(home, label = name)
plt.plot(result, label=result_name)
plt.legend()

plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(동 단위)을 입력해 주세요 : 방이2동
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-ab02fa44deeb> in <module>
#      14 for row in data :
#      15     if name in row[0] :
# ---> 16             home = np.array(row[3:], dtype=int)/int(row[2])
#      17
#      18 for row in data :
#
# ValueError: invalid literal for int() with base 10: '26,081'
