# %%
import numpy as np

# %%
arr = np.array([1, 10, 5, 8, 2, 4, 3, 6, 8, 7, 9])

# %%
np.sort(arr)
# Out:
# array([ 1,  2,  3,  4,  5,  6,  7,  8,  8,  9, 10])

# %%
np.sort(arr)[::-1]
# Out:
# array([10,  9,  8,  8,  7,  6,  5,  4,  3,  2,  1])

# %%
arr2 = np.sort(arr)

# %%
arr2
# Out:
# array([ 1,  2,  3,  4,  5,  6,  7,  8,  8,  9, 10])

# %%
arr
# Out:
# array([ 1, 10,  5,  8,  2,  4,  3,  6,  8,  7,  9])

# %%
arr.sort()

# %%
arr
# Out:
# array([ 1,  2,  3,  4,  5,  6,  7,  8,  8,  9, 10])

# %%
arr2d = np.array([[5, 6, 7, 8], 
                  [4, 3, 2, 1],
                  [10, 9, 12, 11]])

# %%
np.sort(arr2d, axis=1)
# Out:
# array([[ 5,  6,  7,  8],
#        [ 1,  2,  3,  4],
#        [ 9, 10, 11, 12]])

# %%
arr2d
# Out:
# array([[ 5,  6,  7,  8],
#        [ 4,  3,  2,  1],
#        [10,  9, 12, 11]])

# %%
np.sort(arr2d, axis=0)
# Out:
# array([[ 4,  3,  2,  1],
#        [ 5,  6,  7,  8],
#        [10,  9, 12, 11]])

# %%
arr2d = np.array([[5, 6, 7, 8], 
                  [4, 3, 2, 1],
                  [10, 9, 12, 11]])

# %%
np.argsort(arr2d, axis=1)
# Out:
# array([[0, 1, 2, 3],
#        [3, 2, 1, 0],
#        [1, 0, 3, 2]])

# %%
np.argsort(arr2d, axis=0)
# Out:
# array([[1, 1, 1, 1],
#        [0, 0, 0, 0],
#        [2, 2, 2, 2]])

# %%
a = np.array([[1, 2, 3], 
              [2, 3, 4]])

# %%
b = np.array([[3, 4, 5], 
              [1, 2, 3]])

# %%
a+b
# Out:
# array([[4, 6, 8],
#        [3, 5, 7]])

# %%
a = np.array([[1, 2, 3], 
              [2, 3, 4]])

# %%
b = np.array([[1, 2],
              [3, 4],  
              [5, 6]])

# %%
a+b
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-ca730b97bf8a> in <module>()
# ----> 1 a+b
#
# ValueError: operands could not be broadcast together with shapes (2,3) (3,2)

# %%
a = np.array([[1, 2, 3], 
              [2, 3, 4]])

# %%
np.sum(a, axis=0)
# Out:
# array([3, 5, 7])

# %%
np.sum(a, axis=1)
# Out:
# array([6, 9])

# %%
a = np.array([[1, 2, 3], 
              [2, 3, 4]])

# %%
b = np.array([[3, 4, 5], 
              [1, 2, 3]])

# %%
a - b
# Out:
# array([[-2, -2, -2],
#        [ 1,  1,  1]])

# %%
a = np.array([[1, 2, 3], 
              [2, 3, 4]])

# %%
b = np.array([[1, 2],
              [3, 4],  
              [5, 6]])

# %%
a - b
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-09bd029d0285> in <module>()
# ----> 1 a - b
#
# ValueError: operands could not be broadcast together with shapes (2,3) (3,2)

# %%
a = np.array([[1, 2, 3], 
              [2, 3, 4]])

# %%
b = np.array([[3, 4, 5], 
              [1, 2, 3]])

# %%
a.shape, b.shape
# Out:
# ((2, 3), (2, 3))

# %%
a * b
# Out:
# array([[ 3,  8, 15],
#        [ 2,  6, 12]])

# %%
a = np.array([[1, 2, 3], 
              [2, 3, 4]])

# %%
b = np.array([[3, 4, 5], 
              [1, 2, 3]])

# %%
a * b
# Out:
# array([[ 3,  8, 15],
#        [ 2,  6, 12]])

# %%
a = np.array([[1, 2, 3],
              [1, 2, 3], 
              [2, 3, 4]])

# %%
b = np.array([[1, 2],
              [3, 4],  
              [5, 6]])

# %%
a.shape, b.shape
# Out:
# ((3, 3), (3, 2))

# %%
a*b
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-8ce765dcfa30> in <module>()
# ----> 1 a*b
#
# ValueError: operands could not be broadcast together with shapes (3,3) (3,2)

# %%
np.dot(a, b)
# Out:
# array([[22, 28],
#        [22, 28],
#        [31, 40]])

# %%
a.dot(b)
# Out:
# array([[22, 28],
#        [22, 28],
#        [31, 40]])

# %%
1*1 + 2*3 + 3*5
# Out:
# 22

# %%
1*2 + 2*4 + 3*6
# Out:
# 28

# %%
b.dot(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-514ef806ce2e> in <module>()
# ----> 1 b.dot(a)
#
# ValueError: shapes (3,2) and (3,3) not aligned: 2 (dim 1) != 3 (dim 0)

# %%
a = np.array([[1, 2, 3], 
              [2, 3, 4]])

# %%
b = np.array([[3, 3, 3], 
              [3, 3, 3]])

# %%
a + b
# Out:
# array([[4, 5, 6],
#        [5, 6, 7]])

# %%
a + 3
# Out:
# array([[4, 5, 6],
#        [5, 6, 7]])

# %%
a - 3
# Out:
# array([[-2, -1,  0],
#        [-1,  0,  1]])

# %%
a * 3
# Out:
# array([[ 3,  6,  9],
#        [ 6,  9, 12]])

# %%
a / 3
# Out:
# array([[0.33333333, 0.66666667, 1.        ],
#        [0.66666667, 1.        , 1.33333333]])

# %%
a = np.array([[1, 2, 3], 
              [2, 3, 4]])

# %%
b = np.array([[1], 
              [2]])

# %%
a.shape, b.shape
# Out:
# ((2, 3), (2, 1))

# %%
a * b
# Out:
# array([[1, 2, 3],
#        [4, 6, 8]])

# %%
a = np.array([[1, 2, 3], 
              [2, 3, 4]])

# %%
b = np.array([1, 2, 3])

# %%
a * b
# Out:
# array([[ 1,  4,  9],
#        [ 2,  6, 12]])
