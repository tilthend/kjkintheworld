# %%
def my_func(a, b):
    print(a, b)

# %%
my_func(1, 10)
# Out:
# 1 10

# %% [markdown]
# 리턴 있는 경우

# %%
def my_func(a, b):
    s = a+b

    return s

# %%
my_func(1, 10)
# Out:
# 11

# %%
result = my_func(1, 10)

# %%
result
# Out:
# 11

# %%
print(result)
# Out:
# 11

# %%
def my_func(a, b, c):
    return (a + b) * c

# %%
a = 10
b = 20
c = 3

# %%
my_func
# Out:
# <function __main__.my_func>

# %%
my_func(a, b, c)
# Out:
# 90

# %%
my_func(c, b, a)
# Out:
# 230

# %%
1 > 2
# Out:
# False

# %%
10 >= 10
# Out:
# True

# %%
9 < 10
# Out:
# True

# %%
8 <= 7
# Out:
# False

# %%
2 = 2
# Out:
#   File "<ipython-input-19-a8e553549e25>", line 1
#     2 = 2
#          ^
# SyntaxError: can't assign to literal

# %%
2 == 2
# Out:
# True

# %%
2 == 3
# Out:
# False

# %%
2 != 2
# Out:
# False

# %%
'나' != '너'
# Out:
# True

# %%
'나' != '나'
# Out:
# False

# %%
if 5 > 3:
print('참')
# Out:
#   File "<ipython-input-27-b632200fd0c0>", line 2
#     print('참')
#         ^
# IndentationError: expected an indented block

# %%
if 5 > 3:
 print('참')
# Out:
# 참

# %%
if 5 > 3:
    print('참')
# Out:
# 참

# %%
if 5 < 3:
    print('참')
    print('참')
    print('참')
    print('참')

print('끝')
# Out:
# 끝

# %%
if (5 < 3):
    print('참')
    print('참')
    print('참')
    print('참')

print('끝')
# Out:
# 끝

# %%
if (5 > 3):
    print('참')
    print('참')
    print('참')
    print('참')

print('끝')
# Out:
# 참
# 참
# 참
# 참
# 끝

# %%
if 5 < 3:
    print('if 구문 실행')
else:
    print('else 구문 실행')
# Out:
# else 구문 실행

# %%
else:
    print('else 구문 실행')
# Out:
#   File "<ipython-input-32-5018a7ac68d5>", line 1
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
if 3 > 5:
    print('if 구문')
elif 3 < 4:
    print('elif 구문')
else:
    print('이것도 저것도 아니다')
# Out:
# elif 구문

# %%
if 3 > 5:
    print('if 구문')
elif 3 > 4:
    print('elif 1 구문')
elif 3 < 5:
    print('elif 2 구문')
elif 3 < 6:
    print('elif 3 구문')
else:
    print('이것도 저것도 아니다')
# Out:
# elif 2 구문

# %%
if 1:
    print('참')
else:
    print('거짓')
# Out:
# 참

# %%
if 0:
    print('참')
else:
    print('거짓')
# Out:
# 거짓

# %%
True and True and True
# Out:
# True

# %%
True and False and True
# Out:
# False

# %%
if (0 < 1) and (0 < 2):
    print('모두 참')
else:
    print('거짓')
# Out:
# 모두 참

# %%
if (0 < 1) and (0 > 2):
    print('모두 참')
else:
    print('허참')
# Out:
# 허참

# %%
True or False or False
# Out:
# True

# %%
False or False or False
# Out:
# False

# %%
if (0 < 1) or ( 1 < 0):
    print('하나라도 참')
else:
    print('허참')
# Out:
# 하나라도 참

# %%
if (10 < 1) or ( 1 < 0):
    print('하나라도 참')
else:
    print('허참')
# Out:
# 허참
