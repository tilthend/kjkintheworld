# %%
import pandas as pd

# %%
CCTV_Seoul = pd.read_csv('C:/Users/woowahan/Documents/data/Python/datamassage/cctv.csv', encoding = 'utf8')

# %%
CCTV_Seoul.head()
# Out:
#      기관명       소계 2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 0  강 남 구   5,221    1,944   195.0  316.0   430   546.0  765.0  577.0  448.0
# 1  강 동 구   1,879      303   387.0  134.0    59   144.0  194.0  273.0  385.0
# 2  강 북 구   1,265      243    88.0  141.0    74   145.0  254.0    1.0  319.0
# 3  강 서 구   1,617      219   155.0  118.0   230   187.0  190.0  264.0  254.0
# 4  관 악 구   3,985      430    56.0  419.0   487   609.0  619.0  694.0  671.0

# %%
pop_seoul=pd.read_excel('C:/Users/woowahan/Documents/data/Python/datamassage/pop_seoul.xlsx', enconding='utf-8' )

# %%
pop_seoul.head()
# Out:
#       기준일ID  시군구코드 시군구명        총생활인구수      내국인생활인구수   장기체류외국인인구수  단기체류외국인인구수  \
# 0  20201218  11000  서울시  1.090282e+07  1.043842e+07  379579.3655  84819.9178
# 1  20201218  11110  종로구  2.851009e+05  2.670721e+05   15486.6770   2542.1083
# 2  20201218  11140   중구  2.783933e+05  2.520432e+05   18976.8810   7373.2515
# 3  20201218  11170  용산구  3.013044e+05  2.797843e+05   18205.2012   3314.9219
# 4  20201218  11200  성동구  3.594109e+05  3.425431e+05   15032.8670   1834.9967
#
#          일최대인구수        일최소인구수  주간인구수(09~18)  야간인구수(19~08)      일최대이동인구수  \
# 0  1.116026e+07  1.063678e+07  1.112032e+07  1.074746e+07  5.574969e+06
# 1  3.701797e+05  2.206032e+05  3.494647e+05  2.391268e+05  2.337545e+05
# 2  3.961259e+05  1.902078e+05  3.685337e+05  2.140073e+05  2.776604e+05
# 3  3.232275e+05  2.766007e+05  3.209562e+05  2.872674e+05  1.695602e+05
# 4  3.756175e+05  3.388085e+05  3.740402e+05  3.489614e+05  1.918945e+05
#
#        서울외유입인구수  동일자치구행정동간이동인구수     자치구간이동인구수
# ...

# %%
pop_seoul.drop([0], inplace=True)

# %%
pop_seoul
# Out:
#        기준일ID  시군구코드  시군구명       총생활인구수     내국인생활인구수  장기체류외국인인구수  단기체류외국인인구수  \
# 1   20201218  11110   종로구  285100.9320  267072.1466  15486.6770   2542.1083
# 2   20201218  11140    중구  278393.2846  252043.1521  18976.8810   7373.2515
# 3   20201218  11170   용산구  301304.4117  279784.2886  18205.2012   3314.9219
# 4   20201218  11200   성동구  359410.9331  342543.0694  15032.8670   1834.9967
# 5   20201218  11215   광진구  380801.7989  359331.6158  19795.5445   1674.6386
# 6   20201218  11230  동대문구  380626.5265  352523.2585  23108.2471   4995.0209
# 7   20201218  11260   중랑구  363625.5662  356752.9155   6261.8099    610.8408
# 8   20201218  11290   성북구  442839.3882  423466.9152  15555.2003   3817.2727
# 9   20201218  11305   강북구  303600.4687  297630.8965   4991.1925    978.3796
# 10  20201218  11320   도봉구  280932.0730  277410.3784   2980.3546    541.3400
# 11  20201218  11350   노원구  523749.5455  517147.5301   5224.2989   1377.7166
# ...

# %%
CCTV_Seoul.rename(columns={CCTV_Seoul.columns[0] : '시군구명'}, inplace=True)

# %%
CCTV_Seoul.head()
# Out:
#     시군구명       소계 2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 0  강 남 구   5,221    1,944   195.0  316.0   430   546.0  765.0  577.0  448.0
# 1  강 동 구   1,879      303   387.0  134.0    59   144.0  194.0  273.0  385.0
# 2  강 북 구   1,265      243    88.0  141.0    74   145.0  254.0    1.0  319.0
# 3  강 서 구   1,617      219   155.0  118.0   230   187.0  190.0  264.0  254.0
# 4  관 악 구   3,985      430    56.0  419.0   487   609.0  619.0  694.0  671.0

# %%
data_result = pd.merge(CCTV_Seoul, pop_seoul, on='시군구명')

# %%
data_result.head()
# Out:
#    시군구명       소계 2011년 이전  2012년  2013년    2014년  2015년  2016년  2017년  2018년  \
# 0  동대문구   2,003       NaN    NaN    NaN   1,326   111.0  233.0  136.0  197.0
# 1  서대문구   2,121      565   233.0  214.0     114   109.0  277.0  415.0  194.0
# 2  영등포구   2,495      132   121.0  206.0     217   366.0  289.0  371.0  793.0
#
#    ...  장기체류외국인인구수  단기체류외국인인구수       일최대인구수       일최소인구수  주간인구수(09~18)  \
# 0  ...  23108.2471   4995.0209  386239.0668  374270.0723   379113.1042
# 1  ...  20091.6381  11875.9076  403931.7298  382960.5219   396889.6907
# 2  ...  33710.7774   5711.6003  556290.8101  445497.6713   547838.6676
#
#    야간인구수(19~08)     일최대이동인구수    서울외유입인구수  동일자치구행정동간이동인구수    자치구간이동인구수
# 0   381707.5424  180432.2529  26996.0977      74792.0700   78644.0852
# 1   388127.7717  198307.1585  36521.1715      68432.4914   93353.4956
# 2   462926.5589  320088.7444  81636.7105      87418.6940  151033.3399
#
# [3 rows x 24 columns]

# %%
del data_result['2011년 이전']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2011년 이전'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-f2406557fbba> in <module>
# ----> 1 del data_result['2011년 이전']
#
# ...

# %%
data_result.head(2)
# Out:
#    시군구명       소계  2012년  2013년    2014년  2015년  2016년  2017년  2018년     기준일ID  \
# 0  동대문구   2,003     NaN    NaN   1,326   111.0  233.0  136.0  197.0  20201218
# 1  서대문구   2,121   233.0  214.0     114   109.0  277.0  415.0  194.0  20201218
#
#    ...  장기체류외국인인구수  단기체류외국인인구수       일최대인구수       일최소인구수  주간인구수(09~18)  \
# 0  ...  23108.2471   4995.0209  386239.0668  374270.0723   379113.1042
# 1  ...  20091.6381  11875.9076  403931.7298  382960.5219   396889.6907
#
#    야간인구수(19~08)     일최대이동인구수    서울외유입인구수  동일자치구행정동간이동인구수   자치구간이동인구수
# 0   381707.5424  180432.2529  26996.0977      74792.0700  78644.0852
# 1   388127.7717  198307.1585  36521.1715      68432.4914  93353.4956
#
# [2 rows x 23 columns]

# %%
del data_result['2012년']

# %%
del data_result['2013년']
del data_result['2014년']
del data_result['2015년']
del data_result['2016년']
del data_result['2017년']
del data_result['2018년']

# %%
data_result.head(2)
# Out:
#    시군구명       소계     기준일ID  시군구코드       총생활인구수     내국인생활인구수  장기체류외국인인구수  \
# 0  동대문구   2,003   20201218  11230  380626.5265  352523.2585  23108.2471
# 1  서대문구   2,121   20201218  11410  391778.5713  359811.0256  20091.6381
#
#    단기체류외국인인구수       일최대인구수       일최소인구수  주간인구수(09~18)  야간인구수(19~08)  \
# 0   4995.0209  386239.0668  374270.0723   379113.1042   381707.5424
# 1  11875.9076  403931.7298  382960.5219   396889.6907   388127.7717
#
#       일최대이동인구수    서울외유입인구수  동일자치구행정동간이동인구수   자치구간이동인구수
# 0  180432.2529  26996.0977      74792.0700  78644.0852
# 1  198307.1585  36521.1715      68432.4914  93353.4956

# %%
data_result.set_index('시군구명', inplace=True)

# %%
data_result.head()
# Out:
#            소계     기준일ID  시군구코드       총생활인구수     내국인생활인구수  장기체류외국인인구수  \
# 시군구명
# 동대문구   2,003   20201218  11230  380626.5265  352523.2585  23108.2471
# 서대문구   2,121   20201218  11410  391778.5713  359811.0256  20091.6381
# 영등포구   2,495   20201218  11560  498306.6042  458884.2265  33710.7774
#
#       단기체류외국인인구수       일최대인구수       일최소인구수  주간인구수(09~18)  야간인구수(19~08)  \
# 시군구명
# 동대문구   4995.0209  386239.0668  374270.0723   379113.1042   381707.5424
# 서대문구  11875.9076  403931.7298  382960.5219   396889.6907   388127.7717
# 영등포구   5711.6003  556290.8101  445497.6713   547838.6676   462926.5589
#
#          일최대이동인구수    서울외유입인구수  동일자치구행정동간이동인구수    자치구간이동인구수
# 시군구명
# 동대문구  180432.2529  26996.0977      74792.0700   78644.0852
# 서대문구  198307.1585  36521.1715      68432.4914   93353.4956
# 영등포구  320088.7444  81636.7105      87418.6940  151033.3399

# %%
del data_result['시군구코드']

# %%
data_result.head(1)
# Out:
#            소계     기준일ID       총생활인구수     내국인생활인구수  장기체류외국인인구수  단기체류외국인인구수  \
# 시군구명
# 동대문구   2,003   20201218  380626.5265  352523.2585  23108.2471   4995.0209
#
#            일최대인구수       일최소인구수  주간인구수(09~18)  야간인구수(19~08)     일최대이동인구수  \
# 시군구명
# 동대문구  386239.0668  374270.0723   379113.1042   381707.5424  180432.2529
#
#         서울외유입인구수  동일자치구행정동간이동인구수   자치구간이동인구수
# 시군구명
# 동대문구  26996.0977        74792.07  78644.0852

# %%
del data_result['기준일ID']
del data_result['일최대인구수']
del data_result['일최소인구수']
del data_result['주간인구수(09~18)']

# %%
data_result.head(1)
# Out:
#            소계       총생활인구수     내국인생활인구수  장기체류외국인인구수  단기체류외국인인구수  야간인구수(19~08)  \
# 시군구명
# 동대문구   2,003   380626.5265  352523.2585  23108.2471   4995.0209   381707.5424
#
#          일최대이동인구수    서울외유입인구수  동일자치구행정동간이동인구수   자치구간이동인구수
# 시군구명
# 동대문구  180432.2529  26996.0977        74792.07  78644.0852

# %%
del data_result['야간인구수(19~08)']

# %%
data_result.head(1)
# Out:
#            소계       총생활인구수     내국인생활인구수  장기체류외국인인구수  단기체류외국인인구수     일최대이동인구수  \
# 시군구명
# 동대문구   2,003   380626.5265  352523.2585  23108.2471   4995.0209  180432.2529
#
#        자치구간이동인구수
# 시군구명
# 동대문구  78644.0852

# %%
data_result['외국인생활인구수'] = data_result['총생활인구수'] - data_result['내국인생활인구수']

# %%
data_result.head(1)
# Out:
#            소계       총생활인구수     내국인생활인구수  장기체류외국인인구수  단기체류외국인인구수     일최대이동인구수  \
# 시군구명
# 동대문구   2,003   380626.5265  352523.2585  23108.2471   4995.0209  180432.2529
#
#        자치구간이동인구수   외국인생활인구수
# 시군구명
# 동대문구  78644.0852  28103.268

# %%
data_result['외국인생활인구수비율'] = data_result['외국인생활인구수'] / data_result['총생활인구수'] * 100

# %%
data_result.head(1)
# Out:
#            소계       총생활인구수     내국인생활인구수  장기체류외국인인구수  단기체류외국인인구수     일최대이동인구수  \
# 시군구명
# 동대문구   2,003   380626.5265  352523.2585  23108.2471   4995.0209  180432.2529
#
#        자치구간이동인구수   외국인생활인구수  외국인생활인구수비율
# 시군구명
# 동대문구  78644.0852  28103.268    7.383423

# %%
data_result['내국인생활인구수비율'] = data_result['내국인생활인구수'] / data_result['총생활인구수'] * 100

# %%
import numpy as np

# %%
np.corrcoef(data_result['외국인생활인구수비율'], data_result['소계'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-b2ef162e3150> in <module>
# ----> 1 np.corrcoef(data_result['외국인생활인구수비율'], data_result['소계'])
#
# <__array_function__ internals> in corrcoef(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in corrcoef(x, y, rowvar, bias, ddof)
#    2524         warnings.warn('bias and ddof have no effect and are deprecated',
#    2525                       DeprecationWarning, stacklevel=3)
# -> 2526     c = cov(x, y, rowvar)
#    2527     try:
#    2528         d = diag(c)
#
# <__array_function__ internals> in cov(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    2429             w *= aweights
#    2430
# -> 2431     avg, w_sum = average(X, axis=1, weights=w, returned=True)
#    2432     w_sum = w_sum[0]
#    2433
# ...

# %%
data_result['소계1'] = pd.to_numeric(data_result['소계'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " 2,003 "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-8b9462cb2d69> in <module>
# ----> 1 data_result['소계1'] = pd.to_numeric(data_result['소계'])
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     147         coerce_numeric = errors not in ("ignore", "raise")
#     148         try:
# --> 149             values = lib.maybe_convert_numeric(
#     150                 values, set(), coerce_numeric=coerce_numeric
#     151             )
#
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ...

# %%
data_result[data_result['소계'].isnull()]
# Out:
# Empty DataFrame
# Columns: [소계, 총생활인구수, 내국인생활인구수, 장기체류외국인인구수, 단기체류외국인인구수, 일최대이동인구수, 자치구간이동인구수, 외국인생활인구수, 외국인생활인구수비율, 내국인생활인구수비율]
# Index: []
