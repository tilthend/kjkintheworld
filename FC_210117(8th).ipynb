# %%
import pandas as pd

# %%
from pd import DataFrame
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-a40f26d67aed> in <module>()
# ----> 1 from pd import DataFrame
#
# ModuleNotFoundError: No module named 'pd'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from pandas import DataFrame

# %%
DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
 import numpy as np

# %%
np.array
# Out:
# <function numpy.array>

# %%
a = np.array[[1,2,3],[1,2],[3,2]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-c4327e984c78> in <module>()
# ----> 1 a = np.array[[1,2,3],[1,2],[3,2]]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
import numpy as np

# %% [markdown]
# ndarrary 생성

# %%
arr = np.array([1,2,3,4], dtype=int)

# %%
arr
# Out:
# array([1, 2, 3, 4])

# %%
np.shape(arr)
# Out:
# (4,)

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
mylist1 = [1,2,3,4]
mylist2 = [[1,2,3,4],[5,6,7,8]]

# %%
arr1 = np.array(mylist1)

# %%
arr2 = np.array(mylist2)

# %%
arr1
# Out:
# array([1, 2, 3, 4])

# %%
arr2
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
np.shape(arr2)
# Out:
# (2, 4)

# %%
mylist = [1, 3,14, '테디', '1234']

# %%
mylist
# Out:
# [1, 3, 14, '테디', '1234']

# %%
type(mylist)
# Out:
# list

# %%
arr = np.array(mylist)

# %%
arr
# Out:
# array(['1', '3', '14', '테디', '1234'], dtype='<U21')

# %%
arr1 = np.array(mylist, dtype=int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-937510c5ba1b> in <module>()
# ----> 1 arr1 = np.array(mylist, dtype=int)
#
# ValueError: invalid literal for int() with base 10: '테디'
