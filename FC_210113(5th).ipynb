# %%
[]
# Out:
# []

# %%
a = 10
b = 3

# %%
a + b
# Out:
# 13

# %%
10 + 234
# Out:
# 244

# %%
a - b
# Out:
# 7

# %%
a * b
# Out:
# 30

# %%
a = 10
b = 3

# %%
a % b
# Out:
# 1

# %%
a / b
# Out:
# 3.3333333333333335

# %%
a // b
# Out:
# 3

# %%
a**b
# Out:
# 1000

# %%
10**2
# Out:
# 100

# %%
10 + 2 * 5
# Out:
# 20

# %%
(10 + 2) * 5
# Out:
# 60

# %%
a = '반갑습니다.'
b = '테디입니다.'

# %%
a + b
# Out:
# '반갑습니다.테디입니다.'

# %%
a - b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-09bd029d0285> in <module>()
# ----> 1 a - b
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
a * b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-9bc1a869709f> in <module>()
# ----> 1 a * b
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
a / b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-d8e10abd5ab6> in <module>()
# ----> 1 a / b
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
a = '10'
b = '20'

# %%
a+b
# Out:
# '1020'

# %%
# 이렇게 코멘트를 달 수 있습니다.
a = 3
b = 4

# a + b 연산을 수행해 봅시다
print(a + b)
# Out:
# 7

# %%
def my_func():
    print('indent가 자동으로 되나요?')

# %%
def my_func():
print('indent가 자동으로 되나요?')
# Out:
#   File "<ipython-input-24-08806ce53ffc>", line 2
#     print('indent가 자동으로 되나요?')
#         ^
# IndentationError: expected an indented block

# %%
a = 3
    b = 4
# Out:
#   File "<ipython-input-25-a09cf6cf6487>", line 2
#     b = 4
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ## 함수

# %%
a = 1
b = 2
c = 3

# %%
(a + b) * c
# Out:
# 9

# %%
a = 2
b = 2
c = 3

# %%
(a + b) * c
# Out:
# 12

# %% [markdown]
# 함수로 변경 후

# %%
def func(a, b, c):
    return (a + b)*c

# %%
func(1, 2, 3)
# Out:
# 9

# %% [markdown]
# def

# %%
def my_func(apple):
    print(apple*2)

# %%
my_func('안녕하세요')
# Out:
# 안녕하세요안녕하세요
