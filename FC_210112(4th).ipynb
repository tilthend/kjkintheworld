# %%
a = 1

# %%
type(a)
# Out:
# int

# %%
if 1: 
  print('1은 참')
else:
  print('1은 거짓')

# 1은 Ture로 취급
# Out:
# 1은 참

# %%
if 123: 
  print('123은 참으로 취급')
else:
  print('123은 거짓부렁이')
# Out:
# 123은 참으로 취급

# %%
a = 3.14

# %%
type(a)
# Out:
# float

# %% [markdown]
# 소수 입력하면 자동으로 소수 형태로 입력됨

# %%
word = '안녕하세요'

# %%
word
# Out:
# '안녕하세요'

# %%
word1 = "하이욤"

# %%
word1
# Out:
# '하이욤'

# %%
type(word)
# Out:
# str

# %%
a = False

# %%
a
# Out:
# False

# %%
type(a)
# Out:
# bool

# %%
1 == True
# Out:
# True

# %%
1 == 0
# Out:
# False

# %%
a = None

# %%
a

# %%
type(a)
# Out:
# NoneType

# %%
if None:
  print('참?')
else:
  print('거짓')
# Out:
# 거짓

# %%
mylist = []

# %%
mylist
# Out:
# []

# %%
mylist = [1, 3, 2, 4, 5]

# %%
mylist
# Out:
# [1, 3, 2, 4, 5]

# %%
mylist = []

# %%
mylist
# Out:
# []

# %%
mylist.append(2)

# %%
mylist
# Out:
# [2]

# %%
mylist.append([1, 3])

# %%
mylist
# Out:
# [2, [1, 3]]

# %%
mylist.append([5])

# %%
mylist
# Out:
# [2, [1, 3], [5]]

# %%
mylist.append(1)

# %%
mylist
# Out:
# [2, [1, 3], [5], 1]

# %%
mylist.remove([5])

# %%
mylist
# Out:
# [2, [1, 3], 1]

# %%
mylist = [1, 2, 3, 4]

# %%
mylist
# Out:
# [1, 2, 3, 4]

# %%
mylist[0]
# Out:
# 1

# %%
mylist[3]
# Out:
# 4

# %%
mylist[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-50-30998d85754d> in <module>()
# ----> 1 mylist[5]
#
# IndexError: list index out of range

# %%
mylist[-1]
# Out:
# 4

# %%
len(mylist)
# Out:
# 4

# %%
mytuple = (1,2,3,4,5)

# %%
mytuple
# Out:
# (1, 2, 3, 4, 5)

# %%
mytuple.append(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-082a7ea72a51> in <module>()
# ----> 1 mytuple.append(1)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
mytuple[0]
# Out:
# 1

# %%
len(mytuple)
# Out:
# 5

# %%
myset = set()

# %%
myset
# Out:
# set()

# %%
type(myset)
# Out:
# set

# %%
myset.add(1)
myset.add(2)
myset.add(3)

# %%
myset
# Out:
# {1, 2, 3}

# %%
myset.add(1)

# %%
myset
# Out:
# {1, 2, 3}

# %%
myset.remove(1)

# %%
myset
# Out:
# {2, 3}

# %%
mydict = dict()

# %%
mydict
# Out:
# {}

# %%
type(mydict)
# Out:
# dict

# %%
mydict['apple'] = 123

# %%
mydict
# Out:
# {'apple': 123}

# %%
mydict[0] = 2

# %%
mydict
# Out:
# {0: 2, 'apple': 123}

# %%
mydict[3.14] = 1

# %%
mydict
# Out:
# {0: 2, 3.14: 1, 'apple': 123}

# %%
type(mydict)
# Out:
# dict

# %%
len(mydict)
# Out:
# 3

# %%
mydict['apple'] = 'byebye'

# %%
mydict
# Out:
# {0: 2, 3.14: 1, 'apple': 'byebye'}

# %%
mydict.remove(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-86-963f364013af> in <module>()
# ----> 1 mydict.remove(1)
#
# AttributeError: 'dict' object has no attribute 'remove'
